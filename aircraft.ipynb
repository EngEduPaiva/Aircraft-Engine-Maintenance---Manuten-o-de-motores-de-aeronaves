# %% [markdown]
# # Aircraft Engine Maintenance
# ## Manutenção de motores de aeronaves
# (Dataset adiquirido na Kaggle)
#
# **Sobre o conjunto de dados**
#
#      O conjunto de dados trata da manutenção de motores de aeronaves tomando os parâmetros como Tipo de Motor,Tipo de Combustível, Combustão e durabilidade. A precisão da condição do motor pode ser obtida usando algoritmos de regressão de ML, como Máquina de vetor de suporte de árvore de decisão de floresta aleatória de rede neural convencional.

# %%
# Exportar dados

import pandas as pd 

tabela = pd.read_csv("Aircraft_Engine_Maintenance_final.csv")
display (tabela)
# Out:
#                  Model             Company Engine Type Multi Engine  TP mods  \
# 0          15 AC Sedan             Aeronca      Piston          NaN    False
# 1    11 CC Super Chief             Aeronca      Piston          NaN    False
# 2          7 CCM Champ             Aeronca      Piston          NaN    False
# 3           7 DC Champ             Aeronca      Piston          NaN    False
# 4           7 AC Champ             Aeronca      Piston          NaN    False
# ..                 ...                 ...         ...          ...      ...
# 855              500 A  Twin Commander A/C      Piston         True    False
# 856                500  Twin Commander A/C      Piston         True    False
# 857                520  Twin Commander A/C      Piston         True    False
# 858               2180               Varga      Piston          NaN    False
# 859      2150A Kachina               Varga      Piston          NaN    False
#
# ...

# %%
# Identificando valores da tabela.
# Se existe campos vazios que podem atrapalhar na analise dos dados.

display (tabela.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 860 entries, 0 to 859
# Data columns (total 25 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Model         860 non-null    object
#  1   Company       860 non-null    object
#  2   Engine Type   860 non-null    object
#  3   Multi Engine  381 non-null    object
#  4   TP mods       860 non-null    bool
#  5   THR           156 non-null    float64
#  6   SHP           704 non-null    float64
#  7   Length        846 non-null    float64
#  8   Height        843 non-null    float64
#  9   Wing Span     856 non-null    float64
#  10  FW            855 non-null    float64
#  11  MEW           840 non-null    float64
#  12  AUW           857 non-null    float64
#  13  Vmax          817 non-null    float64
#  14  Vcruise       838 non-null    float64
#  15  Vstall        762 non-null    float64
#  16  Hmax          827 non-null    float64
#  17  Hmax (One)    361 non-null    float64
# ...

# %%
# Quantidade e tipos motores.

display (tabela["Engine Type"].value_counts())
display (tabela["Engine Type"].value_counts(normalize=True).map("{:.1%}".format))

# Só temos uma tipo de motor no Dataset.
# Out:
# Engine Type
# Piston     609
# Jet        156
# Propjet     95
# Name: count, dtype: int64
# Engine Type
# Piston     70.8%
# Jet        18.1%
# Propjet    11.0%
# Name: proportion, dtype: object

# %%
# Analisando dados do motor.

display(tabela["Company"].value_counts())
display(tabela["Company"].value_counts(normalize=True).map("{:.1%}".format))
# Out:
# Company
# Cessna Aircraft Company                   204
# Piper Aircraft                            111
# Beechcraft (Hawker Beechcraft)            102
# Bombardier Aerospace Business Aircraft     45
# Twin Commander A/C                         29
#                                          ...
# Quest Aircraft                              1
# B Bar D Aviation, Inc.                      1
# Pilatus Business Aircraft                   1
# Eurofox, Rollison LSA Inc                   1
# Piaggio America                             1
# Name: count, Length: 67, dtype: int64
# Company
# Cessna Aircraft Company                   23.7%
# Piper Aircraft                            12.9%
# Beechcraft (Hawker Beechcraft)            11.9%
# Bombardier Aerospace Business Aircraft     5.2%
# Twin Commander A/C                         3.4%
#                                           ...
# Quest Aircraft                             0.1%
# B Bar D Aviation, Inc.                     0.1%
# ...
